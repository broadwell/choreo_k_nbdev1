# %%
# default_exp detect

# %% [markdown]
# # detect
#
# > Pose Detector class based on Open PifPaf and some pose modification tools

# %%
#hide
from nbdev.showdoc import *

# %%
#hide
#%pip install torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html
#%pip install openpifpaf==0.11.5
#%pip install opencv-python

# !wget https://github.com/vita-epfl/openpifpaf-torchhub/releases/download/v0.11.0/shufflenetv2k30w-200510-104256-cif-caf-caf25-o10s-0b5ba06f.pkl
# Out:
# Requirement already up-to-date: scikit-bio in /Users/pmb/anaconda3/lib/python3.7/site-packages (0.5.6)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.2 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-bio) (1.17.2)
# Requirement already satisfied, skipping upgrade: lockfile>=0.10.2 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-bio) (0.12.2)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.19.1 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-bio) (0.21.3)
# Requirement already satisfied, skipping upgrade: pandas>=1.0.0 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-bio) (1.1.0)
# Requirement already satisfied, skipping upgrade: natsort>=4.0.3 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-bio) (7.0.1)
# Requirement already satisfied, skipping upgrade: hdmedians>=0.13 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-bio) (0.13)
# Requirement already satisfied, skipping upgrade: matplotlib>=1.4.3 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-bio) (3.1.1)
# Requirement already satisfied, skipping upgrade: decorator>=3.4.2 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-bio) (4.4.0)
# Requirement already satisfied, skipping upgrade: IPython>=3.2.0 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-bio) (7.8.0)
# Requirement already satisfied, skipping upgrade: scipy>=1.3.0 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-bio) (1.3.1)
# Requirement already satisfied, skipping upgrade: CacheControl>=0.11.5 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-bio) (0.12.6)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from scikit-learn>=0.19.1->scikit-bio) (0.13.2)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from pandas>=1.0.0->scikit-bio) (2019.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from pandas>=1.0.0->scikit-bio) (2.8.0)
# Requirement already satisfied, skipping upgrade: Cython>=0.23 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from hdmedians>=0.13->scikit-bio) (0.29.13)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from matplotlib>=1.4.3->scikit-bio) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from matplotlib>=1.4.3->scikit-bio) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from matplotlib>=1.4.3->scikit-bio) (2.4.2)
# Requirement already satisfied, skipping upgrade: traitlets>=4.2 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from IPython>=3.2.0->scikit-bio) (4.3.3)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /Users/pmb/anaconda3/lib/python3.7/site-packages (from IPython>=3.2.0->scikit-bio) (4.7.0)
# Requirement already satisfied, skipping upgrade: pygments in /Users/pmb/anaconda3/lib/python3.7/site-packages (from IPython>=3.2.0->scikit-bio) (2.4.2)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<2.1.0,>=2.0.0 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from IPython>=3.2.0->scikit-bio) (2.0.10)
# Requirement already satisfied, skipping upgrade: pickleshare in /Users/pmb/anaconda3/lib/python3.7/site-packages (from IPython>=3.2.0->scikit-bio) (0.7.5)
# Requirement already satisfied, skipping upgrade: appnope; sys_platform == "darwin" in /Users/pmb/anaconda3/lib/python3.7/site-packages (from IPython>=3.2.0->scikit-bio) (0.1.0)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from IPython>=3.2.0->scikit-bio) (0.15.1)
# Requirement already satisfied, skipping upgrade: backcall in /Users/pmb/anaconda3/lib/python3.7/site-packages (from IPython>=3.2.0->scikit-bio) (0.1.0)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in /Users/pmb/.local/lib/python3.7/site-packages (from IPython>=3.2.0->scikit-bio) (47.3.1)
# Requirement already satisfied, skipping upgrade: requests in /Users/pmb/anaconda3/lib/python3.7/site-packages (from CacheControl>=0.11.5->scikit-bio) (2.22.0)
# Requirement already satisfied, skipping upgrade: msgpack>=0.5.2 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from CacheControl>=0.11.5->scikit-bio) (0.6.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /Users/pmb/.local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.0.0->scikit-bio) (1.15.0)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /Users/pmb/anaconda3/lib/python3.7/site-packages (from traitlets>=4.2->IPython>=3.2.0->scikit-bio) (0.2.0)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->IPython>=3.2.0->scikit-bio) (0.6.0)
# Requirement already satisfied, skipping upgrade: wcwidth in /Users/pmb/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython>=3.2.0->scikit-bio) (0.1.7)
# Requirement already satisfied, skipping upgrade: parso>=0.5.0 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->IPython>=3.2.0->scikit-bio) (0.5.1)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from requests->CacheControl>=0.11.5->scikit-bio) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from requests->CacheControl>=0.11.5->scikit-bio) (1.24.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/pmb/.local/lib/python3.7/site-packages (from requests->CacheControl>=0.11.5->scikit-bio) (2020.6.20)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from requests->CacheControl>=0.11.5->scikit-bio) (2.8)
# WARNING: You are using pip version 20.2.2; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/pmb/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.5.1 in /Users/pmb/anaconda3/lib/python3.7/site-packages (1.5.1)
# Requirement already satisfied: torchvision==0.6.1 in /Users/pmb/anaconda3/lib/python3.7/site-packages (0.6.1)
# Requirement already satisfied: numpy in /Users/pmb/anaconda3/lib/python3.7/site-packages (from torch==1.5.1) (1.17.2)
# Requirement already satisfied: future in /Users/pmb/anaconda3/lib/python3.7/site-packages (from torch==1.5.1) (0.18.2)
# Requirement already satisfied: pillow>=4.1.1 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from torchvision==0.6.1) (6.2.0)
# WARNING: You are using pip version 20.2.2; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/pmb/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openpifpaf==0.11.5 in /Users/pmb/anaconda3/lib/python3.7/site-packages (0.11.5)
# Requirement already satisfied: python-json-logger in /Users/pmb/anaconda3/lib/python3.7/site-packages (from openpifpaf==0.11.5) (0.1.11)
# Requirement already satisfied: scipy in /Users/pmb/anaconda3/lib/python3.7/site-packages (from openpifpaf==0.11.5) (1.3.1)
# Requirement already satisfied: torchvision>=0.4 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from openpifpaf==0.11.5) (0.6.1)
# Requirement already satisfied: numpy>=1.16 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from openpifpaf==0.11.5) (1.17.2)
# Requirement already satisfied: pillow in /Users/pmb/anaconda3/lib/python3.7/site-packages (from openpifpaf==0.11.5) (6.2.0)
# Requirement already satisfied: torch>=1.3.1 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from openpifpaf==0.11.5) (1.5.1)
# Requirement already satisfied: pysparkling in /Users/pmb/anaconda3/lib/python3.7/site-packages (from openpifpaf==0.11.5) (0.6.0)
# Requirement already satisfied: future in /Users/pmb/anaconda3/lib/python3.7/site-packages (from torch>=1.3.1->openpifpaf==0.11.5) (0.18.2)
# Requirement already satisfied: requests>=2.6.0 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from pysparkling->openpifpaf==0.11.5) (2.22.0)
# Requirement already satisfied: boto>=2.36.0 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from pysparkling->openpifpaf==0.11.5) (2.49.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from requests>=2.6.0->pysparkling->openpifpaf==0.11.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from requests>=2.6.0->pysparkling->openpifpaf==0.11.5) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pmb/.local/lib/python3.7/site-packages (from requests>=2.6.0->pysparkling->openpifpaf==0.11.5) (2020.6.20)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from requests>=2.6.0->pysparkling->openpifpaf==0.11.5) (2.8)
# WARNING: You are using pip version 20.2.2; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/pmb/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting opencv-python
#   Downloading opencv_python-4.5.1.48-cp37-cp37m-macosx_10_13_x86_64.whl (40.3 MB)
#      |████████████████████████████████| 40.3 MB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.14.5 in /Users/pmb/anaconda3/lib/python3.7/site-packages (from opencv-python) (1.17.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.1.48
# WARNING: You are using pip version 20.2.2; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/pmb/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#export
import torch
import openpifpaf

from PIL import Image
import cv2
import os

class Detector:
    """Given a still image (or video frame), finds poses.
    
    Attributes:  
      device: PyTorch computing resource (GPU or CPU)  
      net: Pose detection neural network model  
      processor: Pose detection image processor  
    """
    
    def __init__(self):
        try:
            self.device = torch.device('cuda')  # if cuda is available
        except:
            self.device = torch.device('cpu')
        
        net_cpu, _ = openpifpaf.network.factory(checkpoint='shufflenetv2k30w-200510-104256-cif-caf-caf25-o10s-0b5ba06f.pkl', download_progress=False)
        self.net = net_cpu.to(self.device)

        # These could be parameters to __init__()
        openpifpaf.decoder.CifSeeds.threshold = 0.5
        openpifpaf.decoder.nms.Keypoints.keypoint_threshold = 0.2
        openpifpaf.decoder.nms.Keypoints.instance_threshold = 0.2
        
        self.processor = openpifpaf.decoder.factory_decode(selt.net.head_nets, basenet_stride=self.net.base_net.stride)

        self.__preprocess__ = openpifpaf.transforms.Compose([
            openpifpaf.transforms.NormalizeAnnotations(),
            openpifpaf.transforms.CenterPadTight(16),
            openpifpaf.transforms.EVAL_TRANSFORM,])

    def __detect_one_or_more_images__(self, batch):
        data = openpifpaf.datasets.PilImageList(batch, preprocess=self.__preprocess__)
        batch_size = len(batch)

        loader = torch.utils.data.DataLoader(
            data, batch_size=batch_size, pin_memory=True, 
            collate_fn=openpifpaf.datasets.collate_images_anns_meta)

        for images_batch, _, __ in loader:
            detections = self.processor.batch(self.net, images_batch, device=self.device)[0]
  
        return detections

    def process_image(self, image_path):
        """ Applies the pose detection model to a single image file. Returns detections. """
        pil_image = Image.open(image_path)
        detections = self.__detect_one_or_more_images__([pil_image], self.processor)
        return detections
    
    def get_poses_from_video(video_file, start_seconds=0.0, end_seconds=0.0, max_frames=0, seconds_to_skip=0.0, images_too=False, write_images=False, folder_name='video_folder'):
        """ Given a video file, extracts video frames as images at `seconds_to_skip` intervals,
            from `start_seconds` to `end_seconds`, and runs `__detect_one_or_more_images__()` on each.
            Returns a list of frame pose data items, which are dictionaries with the following elements:
            { 'frame_id': <the frame's position in this list (not in the entire video, if seconds_to_skip != 0)>, 
              'time': <the frame's timecode within the excerpt (not within the full video, if start_seconds != 0)>,
              'figures': [<OpenPifPaf pose detection objects> for all figures detected in the frame]
              <OPTIONAL> 'image': <a PIL image object for the frame>
            }
            `write_images`, if true, causes the extracted frame images to be written to a folder
            specified by `folder_name`, with the naming scheme `image00001.png`
        """
        
        cap = cv2.VideoCapture(video_file)

        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        print('total frames in video:',total_frames)

        video_framerate = cap.get(cv2.CAP_PROP_FPS)
        print('video FPS:',video_framerate)
        frame_duration = 1 / float(video_framerate)

        frame_count = 0.0
        frames_processed = 0
        timecode = 0.0
        skip_until = start_seconds

        pose_output = []

        if write_images:
            if not os.path.isdir(folder_name):
                os.mkdir(folder_name)
            for filename in os.listdir(folder_name):
                file_path = os.path.join(folder_name, filename)
                if os.path.isfile(file_path) or os.path.islink(file_path):
                    os.unlink(file_path)

        while cap.isOpened() and (frame_count < total_frames):
            ret_val, im = cap.read()

            timecode = frame_count * frame_duration
            frame_count += 1

            if (end_seconds and timecode > end_seconds) or (max_frames and frames_processed >= max_frames):
                return pose_output

            if timecode < start_seconds:
                continue

            if m is None:
                # Might want to retry here
                # print("Missed a frame, continuing...")
                # For now, we'll count a missed frame as a processed frame
                continue

            if seconds_to_skip and timecode < skip_until:
                continue
            else:
                skip_until += seconds_to_skip

            im_height, im_width, im_channels = im.shape

            frame_id = int(round(cap.get(1)))

            # Image doesn't necessarily come in as RGB(A)!
            rgbim = cv2.cvtColor(im, cv2.COLOR_BGR2RGBA)
            pil_image = Image.fromarray(rgbim)

            detections = self.__detect_one_or_more_images__([pil_image])

            print("Frame",frame_count,"of",total_frames,round(timecode,2),"figures",len(detections))

            this_frame_data = {'frame_id': frame_count, 'time': timecode, 'figures': detections} #, 'flipped_figures': flipped_detections, 'zeroified_figures': zeroified_detections}
            if images_too:
                this_frame_data['image'] = rgbim
            if write_images:
                pil_image.save(os.path.join('video_images', 'image' + str(int(frames_processed + 1)).zfill(5) + '.png'), 'PNG')

            pose_output.append(this_frame_data)
            frames_processed += 1

        return pose_output

# %%
show_doc(Detector.process_image)
show_doc(Detector.get_poses_from_video)

# %%
try:
    teddy = Detector()
    detections = teddy.process_image('sample_data/sample1.png')
    print(detections[0])
except:
    print("Unable to instantiate a detector on your system. Do you have PyTorch with CUDA enabled?")
